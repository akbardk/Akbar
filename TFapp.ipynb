# %%
def menu():
    print ("========================================MENU UTAMA===========================================")
    print (" ")
    print ("        Toxic Footwear menyediakan berbagai macam sepatu buatan brand lokal Indonesia        ")
    print ("   Mulai dari brand sepatu yang ngedrama, sampai brand sepatu yang gapeduli ada yang drama   ")
    print ("                                    Yang penting #localpride                                 ")
    print (" Kami juga menyediakan layanan cuci sepatu karena kami tahu anda terlalu malas untuk mencuci ")
    print ("                                Layanan apa yang anda akan gunakan?                          ")
    print (" ")
    print ("masukkan angka pilihan yang Mulia sesuai petunjuk dibawah:")
    print ("1 Untuk layanan pembelian sepatu")
    print ("2 Untuk layanan cuci sepatu")
    print (" ")

def beli():
    print (" ")
    print ("-----------------------------Daftar brand sepatu yang tersedia-------------------------------")
    print ("\n1.Composs \n2.Pentela \n3.Oreip \n4.Jejakkaki \n5.GeoffMin")
    
def cuci():
    print (" ")
    print ("---------------------Daftar pilihan layanan cuci sepatu yang tersedia------------------------")
    print ("\n1.Fastclean \n2.Deepclean \n3.Unyellowing \n4.Repaint+Deepclean \n5.Reglue")
    
def cart() :
    No1= str(input("masukan nama sepatu/layanan cuci : "))
    No2= int(input("masukan harga sepatu/layanan cuci: "))
    No3= int(input("masukan jumlah sepatu/layanan cuci yang dibeli: "))
    Total= (No2*No3)
    print("Total pembayaran: ","Rp.",Total)
    print(" ")
    print(" ")
    print("Silahkan melakukan pembayaran melalui transfer ke rekening kami")
    print(" ")
    print(" ")
    print(" ")
    print(" ")
    out() 
    
    
def out():
    print ("Apakah yang Mulia sudah selesai?")
    print ("y untuk menutup program")
    print ("n untuk kembali ke menu utama")
    print (" ")
    out = input("y/n =")
    if out == "Y":
        exit()
    elif out == "y":
        exit()
    elif out == "N":
        menu()
    elif out == "n":
        menu()
    else :
        print ("404 Not Found, Program akan segera tertutup")
        print (" ")
        print (" ")
        print (" ")
        print (" ")
        print (" ")
        print (" ")
        exit()
        
def kecuali():
    print ("404 Not Found")
    print(" ") 
    print ("y = Menu Utama")
    print ("n = Tutup Program")
    lala = input()
    if lala == "N":
        exit()
    elif lala == "n":
        exit()
    elif lala == "Y":
        menu()
    elif lala == "y":
        menu()
    else :
        print ("404 Not Found, Program akan segera tertutup")
        print (" ")
        print (" ")
        print (" ")
        print (" ")
        print (" ")
        print (" ")
        print (" ")
        print (" ")
        exit()

    
print ("*************************************************")
print ("=======   Selamat Datang Baginda Raja   =========")
print ("=====  Sebelum Melanjutkan Transaksi Anda  ======")
print ("==== Mohon Mengisi Data Diri Terlebih Dahulu ====")
print ("*************************************************")
print (" ")
print ("Nama    :"); nama = input()
print ("Alamat  :"); alamat = input ()
print ("No. Telp:"); telp = input()
print (" ")
print (" ")
print ("Untuk memastikan bahwa anda bukan bot, mohon jawab pertanyaan berikut:")
print ("berapakah nilai dari sin 90 derajat?")
jwb = input()
if jwb == ("1"):
    print ("Oke, anda bukan bot")
    print (" ")
    print ("Selamat menghamburkan uang anda!!!")
else :
    print ("Jawaban anda salah, mending gausah order disini")
    print ("kami hanya melayani para #smartpeople yang berwawasan luas")
    print (" ")
    exit()
        
        
print ("*********************************************************************************************")
print ("#                                     TOXIC FOOTWEAR                                        #")
print ("#                                        Est 2020                                           #")
print ("#                         DIAM adalah EMAS, TOXIC adalah BERLIAN                            #")
print ("*********************************************************************************************")
print (" ")
menu()

#Stock Sepatu
Composs = ("\n=> Stok kosong (tidak diberi jatah gara gara jual pentela")
Pentela = ("\n=> Back to 70's series all color High (size 36-44) Rp. 199,900 \n=> Back to 70's series all color Low (size 36-44) Rp. 179,900 \n=> Public series all color High (size 36-44) Rp. 249,900 \n=> Public series all color Low (size 36-44) Rp. 229,900")
Oreip = ("\n=> Arcwave (size 40-44) Rp. 449,900 \n=> Vulcano (size 40-44) Rp. 399,900 \n=> Astro (size 40-44) Rp. 449,900") 
Jejakkaki = ("\n=> Earth Classic (size 40-44) Rp. 285,000 \n=> Flex Oreo (size 40-44) Rp. 295,000 \n=> Pedro (size 40-44) Rp. 275,000 \n=> Elanor (size 40-44) Rp. 275,000 ")
Geoffmin = ("\n=> Dalton STZ (size 40-44) Rp. 399,000 \n=> Dynamite All-black STZ (size 40-44) Rp. 345,000 \n=> Ethan all color (size 40-44) Rp. 345,000") 
#cuci sepatu
Fastclean = ("\n=> Biasa Rp. 15,000 \n=> +Antar jemput Rp. 20,000")
Deepclean = ("\n=> Biasa Rp. 25,000 \n=> +Antar jemput Rp. 35,000") 
Unyellowing = ("\n=> Biasa Rp. 35,000 \n=> +Antar jemput Rp. 45,000")
Repaint_Deepclean = ("\n=> Biasa Rp. 60,000 \n=> +Antar jemput Rp. 70,000")
Reglue = ("\n=> Biasa Rp. 25,000 \n=> +Antar jemput Rp. 35,000")

while 1:

    rsp = input() 
    if rsp == "1":
        beli()
        print ("\n")
        print ("Cari sepatu merk apa yang Mulia?")
        print (" ")
        print ("masukkan angka pilihan yang Mulia sesuai petunjuk diatas:")
        pilih = input()
        if pilih == "1":
            print (" ")
            print ("**************************************SEPATU COMPOSS*****************************************")
            print ("List Harga Sepatu Composs :")
            print (Composs)
            print (" ")
            print (" ")
            out() 
        elif pilih == "2":
            print (" ")
            print ("******************************************PENTELA********************************************")
            print ("List Harga Sepatu Pentela :")
            print (Pentela)
            print (" ")
            print (" ")
            print ("Yang Mulia ingin langsung beli?")
            print ("ketik y untuk membuka keranjang")
            print ("ketik n untuk kembali ke menu utama")
            print (" ")
            tumbas = input() 
            if tumbas == "Y":
                cart()
            elif tumbas == "y":
                cart() 
            elif tumbas == "N":
                menu()
            elif tumbas == "n":
                menu()
            else :
                kecuali()
        elif pilih == "3":
            print (" ")
            print ("***************************************OREIP INDONESIA***************************************")
            print ("List Harga Sepatu Oreip :")
            print (Oreip)
            print (" ")
            print (" ")
            print ("Yang Mulia ingin langsung beli?")
            print ("ketik y untuk membuka keranjang")
            print ("ketik n untuk kembali ke menu utama")
            print (" ")
            tumbas = input() 
            if tumbas == "Y":
                cart()
            elif tumbas == "y":
                cart() 
            elif tumbas == "N":
                menu()
            elif tumbas == "n":
                menu()
            else :
                kecuali()
        elif pilih == "4":
            print (" ")
            print ("************************************JEJAKKAKI FOOTWEAR***************************************")
            print ("List Harga Sepatu Jejakkaki :")
            print (Jejakkaki)
            print (" ")
            print (" ")
            print ("Yang Mulia ingin langsung beli?")
            print ("ketik y untuk membuka keranjang")
            print ("ketik n untuk kembali ke menu utama")
            print (" ")
            tumbas = input() 
            if tumbas == "Y":
                cart()
            elif tumbas == "y":
                cart() 
            elif tumbas == "N":
                menu()
            elif tumbas == "n":
                menu()
            else :
                kecuali()
        elif pilih == "5":
            print (" ")
            print ("*****************************************GEOFFMIN********************************************")
            print ("List Harga Sepatu Geoffmin :")
            print (Geoffmin)
            print (" ")
            print (" ")
            print ("Yang Mulia ingin langsung beli?")
            print ("ketik y untuk membuka keranjang")
            print ("ketik n untuk kembali ke menu utama")
            print (" ")
            tumbas = input() 
            if tumbas == "Y":
                cart()
            elif tumbas == "y":
                cart() 
            elif tumbas == "N":
                menu()
            elif tumbas == "n":
                menu()
            else :
                kecuali() 
        else:
            print ("404 Not Found, Program akan segera tertutup")
            print (" ")
            print (" ")
            print (" ")
            print (" ")
            print (" ")
            print (" ")
            print (" ")
            print (" ")
            exit()  
                
    elif rsp == "2":
        cuci() 
        print ("\n")
        print ("Layanan apa yang Mulia inginkan?")
        print (" ")
        print ("masukkan angka pilihan yang Mulia sesuai petunjuk diatas:")
        mau = input()
        if mau == "1":
            print (" ")
            print ("****************************************FASTCLEAN*******************************************")
            print ("Harga Layanan Fastclean (luar):")
            print (Fastclean)
            print (" ")
            print (" ")
            print ("Yang Mulia ingin menggunakan layanan ini?")
            print ("ketik y untuk membuka keranjang")
            print ("ketik n untuk kembali ke menu utama")
            print (" ")
            tumbas = input() 
            if tumbas == "Y":
                cart()
            elif tumbas == "y":
                cart() 
            elif tumbas == "N":
                menu()
            elif tumbas == "n":
                menu()
            else :
                kecuali()
        elif mau == "2":
            print (" ")
            print ("****************************************DEEPCLEAN*******************************************")
            print ("Harga Layanan Deepclean:")
            print (Deepclean)
            print (" ")
            print (" ")
            print ("Yang Mulia ingin menggunakan layanan ini?")
            print ("ketik y untuk membuka keranjang")
            print ("ketik n untuk kembali ke menu utama")
            print (" ")
            tumbas = input() 
            if tumbas == "Y":
                cart()
            elif tumbas == "y":
                cart() 
            elif tumbas == "N":
                menu()
            elif tumbas == "n":
                menu()
            else :
                kecuali()
        
        elif mau == "3":
            print (" ")
            print ("****************************************UNYELLOWING*******************************************")
            print ("Harga Layanan Unyellowing:")
            print (Unyellowing)
            print (" ")
            print (" ")
            print ("Yang Mulia ingin menggunakan layanan ini?")
            print ("ketik y untuk membuka keranjang")
            print ("ketik n untuk kembali ke menu utama")
            print (" ")
            tumbas = input() 
            if tumbas == "Y":
                cart()
            elif tumbas == "y":
                cart() 
            elif tumbas == "N":
                menu()
            elif tumbas == "n":
                menu()
            else :
                kecuali()
        elif mau == "4":
            print (" ")
            print ("*************************************REPAINT+DEEPCLEAN****************************************")
            print ("Harga Layanan Repaint+Deepclean:")
            print (Repaint_Deepclean)
            print (" ")
            print (" ")
            print ("Yang Mulia ingin menggunakan layanan ini?")
            print ("ketik y untuk membuka keranjang")
            print ("ketik n untuk kembali ke menu utama")
            print (" ")
            tumbas = input() 
            if tumbas == "Y":
                cart()
            elif tumbas == "y":
                cart() 
            elif tumbas == "N":
                menu()
            elif tumbas == "n":
                menu()
            else :
                kecuali()
        elif mau == "5":
            print (" ")
            print ("****************************************REGLUE*******************************************")
            print ("Harga Layanan Reglue:")
            print (Reglue)
            print (" ")
            print (" ")
            print ("Yang Mulia ingin menggunakan layanan ini?")
            print ("ketik y untuk membuka keranjang")
            print ("ketik n untuk kembali ke menu utama")
            print (" ")
            tumbas = input() 
            if tumbas == "Y":
                cart()
            elif tumbas == "y":
                cart() 
            elif tumbas == "N":
                menu()
            elif tumbas == "n":
                menu()
            else :
                kecuali()
        else :
            print ("404 Not Found, Program akan segera tertutup")
            print (" ")
            print (" ")
            print (" ")
            print (" ")
            print (" ")
            print (" ")
            print (" ")
            print (" ")
            exit()
    else :
        print ("404 Not Found, Program akan segera tertutup")
        print (" ")
        print (" ")
        print (" ")
        print (" ")
        print (" ")
        print (" ")
        print (" ")
        print (" ")
        exit()
# Out:
# *************************************************
# =======   Selamat Datang Baginda Raja   =========
# =====  Sebelum Melanjutkan Transaksi Anda  ======
# ==== Mohon Mengisi Data Diri Terlebih Dahulu ====
# *************************************************
#
# Nama    :
# Akbar
# Alamat  :
# Mojo
# No. Telp:
# 012312038129310
#
#
# Untuk memastikan bahwa anda bukan bot, mohon jawab pertanyaan berikut:
# berapakah nilai dari sin 90 derajat?
# 1
# Oke, anda bukan bot
#
# Selamat menghamburkan uang anda!!!
# *********************************************************************************************
# #                                     TOXIC FOOTWEAR                                        #
# #                                        Est 2020                                           #
# #                         DIAM adalah EMAS, TOXIC adalah BERLIAN                            #
# *********************************************************************************************
#
# ...
